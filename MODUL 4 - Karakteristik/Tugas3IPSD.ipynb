# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_features = pd.read_csv('train_features.csv')
test_features = pd.read_csv('test_features.csv')
features = pd.concat([train_features, test_features], axis=1)

# %%
features.head()
# Out:
#    tahun_kelahiran pendidikan status_pernikahan   pendapatan  \
# 0           1979.0    Sarjana   Rencana Menikah          NaN
# 1           1950.0    Sarjana   Rencana Menikah   84063000.0
# 2           1966.0    Sarjana           Menikah  127532564.0
# 3           1961.0   Magister   Rencana Menikah  165579620.0
# 4           1970.0    Sarjana   Rencana Menikah  117703159.0
#
#    jumlah_anak_balita  jumlah_anak_remaja  terakhir_belanja  belanja_buah  \
# 0                 0.0                 1.0               NaN       50575.0
# 1                 NaN                 NaN              70.0        6069.0
# 2                 0.0                 0.0              45.0      117611.0
# 3                 0.0                 0.0              90.0      206346.0
# 4                 1.0                 1.0              78.0       90563.0
#
#    belanja_daging  belanja_ikan  ...  terakhir_belanja  belanja_buah  \
# 0        260967.0       50575.0  ...              63.0      122277.0
# ...

# %%
features.describe().T
# Out:
#                      count          mean           std        min  \
# tahun_kelahiran     3817.0  1.967824e+03  1.176813e+01     1899.0
# pendapatan          3627.0  1.144832e+08  4.346042e+07  5073000.0
# jumlah_anak_balita  3627.0  2.930797e-01  4.730627e-01        0.0
# jumlah_anak_remaja  3613.0  3.537227e-01  4.930139e-01        0.0
# terakhir_belanja    3645.0  4.723155e+01  2.706851e+01        0.0
# belanja_buah        3636.0  5.980424e+04  7.402498e+04        0.0
# belanja_daging      3639.0  4.385748e+05  5.120427e+05        0.0
# belanja_ikan        3624.0  8.142900e+04  9.997623e+04        0.0
# belanja_kue         3603.0  6.337797e+04  7.943546e+04        0.0
# pembelian_diskon    3639.0  2.125584e+00  2.100133e+00        0.0
# pembelian_web       3652.0  4.436473e+00  3.002522e+00        0.0
# pembelian_toko      3648.0  5.767818e+00  3.210738e+00        0.0
# keluhan             3621.0  4.971002e-03  7.033959e-02        0.0
# ...

# %%
train_features.describe().T
# Out:
#                      count          mean           std        min         25%  \
# tahun_kelahiran     3817.0  1.967824e+03  1.176813e+01     1899.0      1959.0
# pendapatan          3627.0  1.144832e+08  4.346042e+07  5073000.0  81125122.0
# jumlah_anak_balita  3627.0  2.930797e-01  4.730627e-01        0.0         0.0
# jumlah_anak_remaja  3613.0  3.537227e-01  4.930139e-01        0.0         0.0
# terakhir_belanja    3645.0  4.723155e+01  2.706851e+01        0.0        25.0
# belanja_buah        3636.0  5.980424e+04  7.402498e+04        0.0      7907.0
# belanja_daging      3639.0  4.385748e+05  5.120427e+05        0.0     49479.5
# belanja_ikan        3624.0  8.142900e+04  9.997623e+04        0.0     10115.0
# belanja_kue         3603.0  6.337797e+04  7.943546e+04        0.0      7947.0
# pembelian_diskon    3639.0  2.125584e+00  2.100133e+00        0.0         0.0
# pembelian_web       3652.0  4.436473e+00  3.002522e+00        0.0         2.0
# ...

# %%
test_features.describe().T
# Out:
#                      count          mean           std        min  \
# ID                  3818.0  3.841507e+03  2.198401e+03        2.0
# tahun_kelahiran     3818.0  1.967790e+03  1.180857e+01     1892.0
# pendapatan          3615.0  1.163249e+08  5.105122e+07  2998899.0
# jumlah_anak_balita  3609.0  2.829039e-01  4.650046e-01        0.0
# jumlah_anak_remaja  3608.0  3.553215e-01  4.968651e-01        0.0
# terakhir_belanja    3617.0  4.718137e+01  2.694029e+01        0.0
# belanja_buah        3632.0  6.123408e+04  7.664759e+04        0.0
# belanja_daging      3623.0  4.528484e+05  5.123206e+05        0.0
# belanja_ikan        3622.0  8.533861e+04  1.037895e+05        0.0
# belanja_kue         3631.0  6.380151e+04  7.842854e+04        0.0
# pembelian_diskon    3639.0  2.101676e+00  2.115571e+00        0.0
# pembelian_web       3638.0  4.465091e+00  2.935615e+00        0.0
# pembelian_toko      3632.0  5.835628e+00  3.288349e+00        0.0
# ...

# %% [markdown]
# Terdapat beberapa perbedaan karakteristik pada dua data diatas yaitu:
# 1. Jumlah Data yang Valid (count)
# Pada data train features, kolom seperti tahun_kelahiran memiliki 3817 entri valid, sementara pada pada data test features, jumlah entri valid untuk kolom yang sama adalah 3818.
# Perbedaan ini menunjukkan bahwa dataset di kedua data memiliki satu baris tambahan yang valid untuk beberapa kolom.
#
# 2. Nilai mean (Rata-rata)
# Ada perbedaan dalam nilai rata-rata untuk beberapa kolom. Pendapatan pada data train features memiliki rata-rata 1.144832e+08, sedangkan pada data test features rata-rata adalah 1.163249e+08. Hal ini menunjukkan adanya perbedaan dalam nilai data antara kedua dataset tersebut, mungkin karena penambahan atau penghapusan entri tertentu.
#
# 3. Nilai std (Standar Deviasi)
# Standar deviasi di beberapa kolom juga berbeda. Misalnya, pada kolom belanja_daging, standar deviasi pada dataset train features adalah 5.120427e+05, sedangkan pada dataset test features adalah 5.123206e+05.
# Ini menunjukkan bahwa penyebaran data di kedua dataset sedikit berbeda.
#
# 4. Nilai Minimum (min) dan Maksimum (max)
# Beberapa nilai minimum dan maksimum antara kedua datasdet tidak sama. Misalnya:
# Pada kolom belanja_daging, nilai maksimum pada dataset train features  adalah 3.489675e+06, sedangkan pada dataset test features adalah 3.271191e+06. Ini mengindikasikan bahwa terdapat perbedaan nilai ekstrim di antara dataset yang dibandingkan.
#
# 5. Percentile (25%, 50%, 75%)
# Perbedaan kecil juga terjadi pada nilai kuartil pertama (25%), median (50%), dan kuartil ketiga (75%). Pada
# Kolom belanja_buah memiliki nilai median 26.456 pada dataset train features, sementara pada dataset test features nilai median adalah 29.525.
# Ini menunjukkan perbedaan distribusi data di kedua dataset.

# %%
num_cols = [
    'tahun_kelahiran',
    'pendapatan',
    'belanja_buah',
    'belanja_daging',
    'belanja_ikan',
    'belanja_kue',
    'pembelian_diskon'
]

# %%
corr = features[num_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='Blues', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Pada korelasi diatas yang merupakan representasi visual dari koefisien korelasi antara berbagai variabel dalam suatu dataset. Variabel-variabel tersebut tercantum di sumbu x dan y, dan nilai-nilai dalam gambar diatas mewakili koefisien korelasi antara variabel-variabel yang bersesuaian.
#
# Koefisien korelasi berkisar antara -1 hingga 1, di mana -1 menunjukkan korelasi negatif yang kuat, menunjukkan tidak ada korelasi, dan 1 menunjukkan korelasi positif yang kuat. pada gambar diatas menggunakan skala warna untuk mewakili nilai-nilai korelasi yang berbeda, dengan biru tua menunjukkan korelasi positif yang lebih kuat dan merah tua menunjukkan korelasi negatif yang lebih kuat.
#
# Sebagai contoh, koefisien korelasi antara "belanja_daging" dan "belanja_daging" adalah 1,00, yang menunjukkan korelasi positif sempurna antara dua variabel ini. Di sisi lain, koefisien korelasi antara "tahun_kelahiran" dan "pendapatan" adalah -0,19, yang menunjukkan korelasi negatif yang lemah antara dua variabel ini.

# %%
features.isnull().sum()
# Out:
# tahun_kelahiran               1
# pendidikan                  190
# status_pernikahan           213
# pendapatan                  191
# jumlah_anak_balita          191
# jumlah_anak_remaja          205
# terakhir_belanja            173
# belanja_buah                182
# belanja_daging              179
# belanja_ikan                194
# belanja_kue                 215
# pembelian_diskon            179
# pembelian_web               166
# pembelian_toko              170
# keluhan                     197
# tanggal_menjadi_anggota    2753
# ID                            0
# tahun_kelahiran               0
# pendidikan                  204
# status_pernikahan           182
# pendapatan                  203
# jumlah_anak_balita          209
# jumlah_anak_remaja          210
# terakhir_belanja            201
# belanja_buah                186
# belanja_daging              195
# belanja_ikan                196
# belanja_kue                 187
# pembelian_diskon            179
# ...
